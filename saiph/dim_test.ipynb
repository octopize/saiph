# %%
from saiph.projection import fit, stats, inverse_transform
from visualization import plot_circle, plot_explained_var, plot_var_contribution
import pandas as pd
import numpy as np

from dataclasses import asdict

# %%
df = pd.read_csv('iris.csv')
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
coord, model, param = fit(df, nf = 'all')
coord
# Out:
# FAMD is performed for dimension reduction
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_18724/353199714.py in <module>
# ----> 1 coord, model, param = fit(df, nf = 'all')
#       2 coord
#
# ~/Documents/projets/saiph/saiph/projection.py in fit(df, nf, col_w, scale)
#      58     else:
#      59         print("FAMD is performed for dimension reduction")
# ---> 60         fit = famd.fit
#      61
#      62     coord, model, param = fit(df, nf, col_w, scale)
#
# NameError: name 'famd' is not defined

# %%
df = pd.read_csv('iris.csv')
coord, model, param = fit(df[['variety']])

coord, model, param = fit(df.drop(['variety'], axis = 1))
coord, model, param = fit(df, nf=4)

coord

# %%
model.mean
# Out:
# array([2.87500e+01, 1.38000e+02, 0.00000e+00, 1.75000e-03, 2.62500e-03,
#        2.50000e-04, 0.00000e+00, 0.00000e+00, 6.10000e+01, 5.12500e-01,
#        4.11250e+01, 6.52500e+00, 3.10000e+01, 1.25500e+02, 1.56500e+02,
#        1.75000e+00, 1.25000e-01, 1.43750e+02, 1.41750e+02, 1.43625e+02,
#        1.50000e+00, 1.25000e-01, 2.00000e+00])

# %%
print(asdict(model).keys())
print(asdict(param).keys())
# ici cos2 contrib et cor sont None (as well as D_c)
# Out:
# dict_keys(['df', 'V', 'explained_var', 'explained_var_ratio', 'variable_coord', 'U', 's', 'mean', 'std', 'prop', '_modalities', 'D_c'])
# dict_keys(['nf', 'col_w', 'row_w', 'columns', 'quanti', 'quali', 'datetime_variables', 'cor', 'contrib', 'cos2'])

# %%
# stats peut prendre un peu de temps s'il s; agit de plusieurs variables et indivuds (50000+)
param = stats(model, param)
print(param.cos2)
# Out:
#                                                       Dim. 0    Dim. 1  \
# Unnamed: 0                                          0.183477  0.321403
# baseline value                                      0.741256  0.201364
# accelerations                                            NaN       NaN
# fetal_movement                                      0.424727  0.111575
# uterine_contractions                                0.801019  0.000206
# light_decelerations                                 0.405638  0.299673
# severe_decelerations                                     NaN       NaN
# prolongued_decelerations                                 NaN       NaN
# abnormal_short_term_variability                     0.550856  0.043690
# mean_value_of_short_term_variability                0.336166  0.063905
# percentage_of_time_with_abnormal_long_term_vari...  0.008109  0.652407
# mean_value_of_long_term_variability                 0.229514  0.436387
# histogram_width                                     0.084038  0.168890
# histogram_min                                       0.542007  0.035938
# histogram_max                                       0.153663  0.195955
# histogram_number_of_peaks                           0.168899  0.701928
# histogram_number_of_zeroes                          0.145646  0.410236
# histogram_mode                                      0.883286  0.054850
# histogram_mean                                      0.907906  0.067358
# histogram_median                                    0.882930  0.090549
# histogram_variance                                  0.002172  0.260318
# histogram_tendency                                  0.091649  0.245160
# fetal_health                                             NaN       NaN
#
#                                                       Dim. 2    Dim. 3  \
# Unnamed: 0                                          0.020463  0.292490
# baseline value                                      0.033856  0.001225
# accelerations                                            NaN       NaN
# fetal_movement                                      0.067761  0.259639
# uterine_contractions                                0.018283  0.031784
# light_decelerations                                 0.183608  0.066633
# severe_decelerations                                     NaN       NaN
# prolongued_decelerations                                 NaN       NaN
# abnormal_short_term_variability                     0.077881  0.057791
# mean_value_of_short_term_variability                0.484780  0.000124
# percentage_of_time_with_abnormal_long_term_vari...  0.077508  0.149502
# mean_value_of_long_term_variability                 0.086437  0.228164
# histogram_width                                     0.722616  0.021314
# histogram_min                                       0.275749  0.071169
# histogram_max                                       0.577896  0.005755
# histogram_number_of_peaks                           0.110998  0.002723
# histogram_number_of_zeroes                          0.024316  0.239941
# histogram_mode                                      0.004184  0.025881
# histogram_mean                                      0.000750  0.008704
# histogram_median                                    0.003431  0.011148
# histogram_variance                                  0.437918  0.073081
# histogram_tendency                                  0.032766  0.272957
# fetal_health                                             NaN       NaN
#
#                                                       Dim. 4    Dim. 5  \
# Unnamed: 0                                          0.034788  0.030007
# baseline value                                      0.002296  0.017550
# accelerations                                            NaN       NaN
# fetal_movement                                      0.094665  0.034605
# uterine_contractions                                0.082165  0.032530
# light_decelerations                                 0.006550  0.036325
# severe_decelerations                                     NaN       NaN
# prolongued_decelerations                                 NaN       NaN
# abnormal_short_term_variability                     0.092837  0.168497
# mean_value_of_short_term_variability                0.064220  0.033933
# percentage_of_time_with_abnormal_long_term_vari...  0.003434  0.080769
# mean_value_of_long_term_variability                 0.000086  0.004528
# histogram_width                                     0.002691  0.000126
# histogram_min                                       0.044336  0.016092
# histogram_max                                       0.026338  0.027707
# histogram_number_of_peaks                           0.008747  0.005555
# histogram_number_of_zeroes                          0.094237  0.044775
# histogram_mode                                      0.022742  0.008256
# histogram_mean                                      0.005905  0.009354
# histogram_median                                    0.004174  0.007698
# histogram_variance                                  0.220876  0.000539
# histogram_tendency                                  0.347324  0.000390
# fetal_health                                             NaN       NaN
#
#                                                       Dim. 6    Dim. 7
# Unnamed: 0                                          0.117372  0.097145
# baseline value                                      0.002454  0.060097
# accelerations                                            NaN       NaN
# fetal_movement                                      0.007027  0.014084
# uterine_contractions                                0.034013  0.230451
# light_decelerations                                 0.001573  0.754092
# severe_decelerations                                     NaN       NaN
# prolongued_decelerations                                 NaN       NaN
# abnormal_short_term_variability                     0.008448  0.265696
# mean_value_of_short_term_variability                0.016872  0.302600
# percentage_of_time_with_abnormal_long_term_vari...  0.028272  0.367657
# mean_value_of_long_term_variability                 0.014884  0.839678
# histogram_width                                     0.000325  0.139215
# histogram_min                                       0.014708  0.274305
# histogram_max                                       0.012687  0.000083
# histogram_number_of_peaks                           0.001149  0.668158
# histogram_number_of_zeroes                          0.040850  0.004549
# histogram_mode                                      0.000801  0.272970
# histogram_mean                                      0.000023  0.233231
# histogram_median                                    0.000069  0.203104
# histogram_variance                                  0.005096  0.280313
# histogram_tendency                                  0.009754  0.005005
# fetal_health                                             NaN       NaN

# %%
param.contrib
# Out:
#                                                        Dim. 0     Dim. 1  \
# Unnamed: 0                                           2.432431   7.368597
# baseline value                                       9.827129   4.616538
# accelerations                                             NaN        NaN
# fetal_movement                                       5.630782   2.558011
# uterine_contractions                                10.619426   0.004722
# light_decelerations                                  5.377704   6.870418
# severe_decelerations                                      NaN        NaN
# prolongued_decelerations                                  NaN        NaN
# abnormal_short_term_variability                      7.302915   1.001654
# mean_value_of_short_term_variability                 4.456687   1.465118
# percentage_of_time_with_abnormal_long_term_vari...   0.107500  14.957317
# mean_value_of_long_term_variability                  3.042756  10.004767
# histogram_width                                      1.114127   3.872040
# histogram_min                                        7.185608   0.823924
# histogram_max                                        2.037170   4.492531
# histogram_number_of_peaks                            2.239160  16.092644
# histogram_number_of_zeroes                           1.930882   9.405215
# histogram_mode                                      11.710072   1.257512
# histogram_mean                                      12.036474   1.544266
# histogram_median                                    11.705356   2.075958
# histogram_variance                                   0.028795   5.968151
# histogram_tendency                                   1.215025   5.620618
# fetal_health                                              NaN        NaN
#
#                                                        Dim. 2     Dim. 3  \
# Unnamed: 0                                           0.631346  16.070642
# baseline value                                       1.044563   0.067296
# accelerations                                             NaN        NaN
# fetal_movement                                       2.090627  14.265655
# uterine_contractions                                 0.564077   1.746358
# light_decelerations                                  5.664829   3.661079
# severe_decelerations                                      NaN        NaN
# prolongued_decelerations                                  NaN        NaN
# abnormal_short_term_variability                      2.402856   3.175274
# mean_value_of_short_term_variability                14.956796   0.006835
# percentage_of_time_with_abnormal_long_term_vari...   2.391322   8.214287
# mean_value_of_long_term_variability                  2.666806  12.536323
# histogram_width                                     22.294687   1.171098
# histogram_min                                        8.507620   3.910345
# histogram_max                                       17.829685   0.316189
# histogram_number_of_peaks                            3.424606   0.149640
# histogram_number_of_zeroes                           0.750201  13.183367
# histogram_mode                                       0.129082   1.422000
# histogram_mean                                       0.023138   0.478253
# histogram_median                                     0.105865   0.612544
# histogram_variance                                  13.510966   4.015378
# histogram_tendency                                   1.010929  14.997437
# fetal_health                                              NaN        NaN
#
#                                                        Dim. 4     Dim. 5  \
# Unnamed: 0                                           3.003082   5.365645
# baseline value                                       0.198166   3.138128
# accelerations                                             NaN        NaN
# fetal_movement                                       8.171967   6.187970
# uterine_contractions                                 7.092931   5.816783
# light_decelerations                                  0.565430   6.495405
# severe_decelerations                                      NaN        NaN
# prolongued_decelerations                                  NaN        NaN
# abnormal_short_term_variability                      8.014187  30.129719
# mean_value_of_short_term_variability                 5.543785   6.067746
# percentage_of_time_with_abnormal_long_term_vari...   0.296420  14.442728
# mean_value_of_long_term_variability                  0.007402   0.809704
# histogram_width                                      0.232260   0.022608
# histogram_min                                        3.827345   2.877441
# histogram_max                                        2.273597   4.954498
# histogram_number_of_peaks                            0.755113   0.993342
# histogram_number_of_zeroes                           8.134996   8.006479
# histogram_mode                                       1.963249   1.476317
# histogram_mean                                       0.509730   1.672723
# histogram_median                                     0.360349   1.376590
# histogram_variance                                  19.067172   0.096448
# histogram_tendency                                  29.982820   0.069726
# fetal_health                                              NaN        NaN
#
#                                                        Dim. 6     Dim. 7
# Unnamed: 0                                          37.098886   1.938087
# baseline value                                       0.775584   1.198964
# accelerations                                             NaN        NaN
# fetal_movement                                       2.221077   0.280972
# uterine_contractions                                10.750901   4.597598
# light_decelerations                                  0.497197  15.044431
# severe_decelerations                                      NaN        NaN
# prolongued_decelerations                                  NaN        NaN
# abnormal_short_term_variability                      2.670286   5.300734
# mean_value_of_short_term_variability                 5.332752   6.036992
# percentage_of_time_with_abnormal_long_term_vari...   8.936145   7.334908
# mean_value_of_long_term_variability                  4.704642  16.751905
# histogram_width                                      0.102653   2.777390
# histogram_min                                        4.649015   5.472487
# histogram_max                                        4.009992   0.001660
# histogram_number_of_peaks                            0.363265  13.330009
# histogram_number_of_zeroes                          12.911958   0.090756
# histogram_mode                                       0.253206   5.445860
# histogram_mean                                       0.007187   4.653044
# histogram_median                                     0.021701   4.052003
# histogram_variance                                   1.610604   5.592353
# histogram_tendency                                   3.082950   0.099848
# fetal_health                                              NaN        NaN

# %%
inverse_transform(coord, model, param)
# warning for less dimensions 
# nf?
# Out:
#    Unnamed: 0  baseline value  accelerations  fetal_movement  \
# 0           7           128.0           -0.0           0.005
# 1          10           152.0            0.0          -0.000
# 2          17           130.0            0.0           0.002
# 3          36           138.0           -0.0           0.005
# 4          38           129.0           -0.0           0.002
# 5          39           140.0           -0.0           0.000
# 6          40           149.0           -0.0           0.000
# 7          43           138.0            0.0           0.000
#
#    uterine_contractions  light_decelerations  severe_decelerations  \
# 0                 0.000                0.000                   0.0
# 1                 0.003                0.000                  -0.0
# 2                -0.000                0.002                  -0.0
# 3                 0.003                0.000                  -0.0
# 4                 0.000                0.000                   0.0
# 5                 0.006               -0.000                   0.0
# 6                 0.006               -0.000                  -0.0
# 7                 0.003                0.000                   0.0
#
#    prolongued_decelerations  abnormal_short_term_variability  \
# 0                       0.0                             74.0
# 1                       0.0                             61.0
# 2                       0.0                             75.0
# 3                       0.0                             62.0
# 4                       0.0                             69.0
# 5                       0.0                             42.0
# 6                       0.0                             61.0
# 7                       0.0                             44.0
#
#    mean_value_of_short_term_variability  ...  histogram_min  histogram_max  \
# 0                                   0.2  ...          122.0          144.0
# 1                                   0.4  ...          129.0          163.0
# 2                                   0.3  ...          105.0          165.0
# 3                                   0.5  ...          121.0          148.0
# 4                                   0.3  ...          127.0          152.0
# 5                                   1.4  ...          124.0          172.0
# 6                                   0.4  ...          146.0          159.0
# 7                                   0.6  ...          130.0          149.0
#
#    histogram_number_of_peaks  histogram_number_of_zeroes  histogram_mode  \
# 0                        1.0                        -0.0           133.0
# 1                        3.0                         1.0           160.0
# 2                        6.0                         0.0           130.0
# 3                        1.0                        -0.0           142.0
# 4                        0.0                         0.0           139.0
# 5                        1.0                         0.0           151.0
# 6                        1.0                         0.0           154.0
# 7                        1.0                         0.0           141.0
#
#    histogram_mean  histogram_median  histogram_variance  histogram_tendency  \
# 0           130.0             132.0                 1.0                -0.0
# 1           157.0             160.0                 1.0                 1.0
# 2           129.0             131.0                 1.0                 0.0
# 3           140.0             142.0                 1.0                 1.0
# 4           135.0             136.0                 4.0                -1.0
# 5           150.0             151.0                 4.0                 0.0
# 6           153.0             155.0                 0.0                 0.0
# 7           140.0             142.0                 0.0                 0.0
#
#    fetal_health
# 0           2.0
# 1           2.0
# 2           2.0
# 3           2.0
# 4           2.0
# 5           2.0
# 6           2.0
# 7           2.0
#
# [8 rows x 23 columns]

# %%
df

# %%
param.cor
# Out:
#                                                       Dim. 0    Dim. 1  \
# Unnamed: 0                                         -0.428342 -0.566924
# baseline value                                     -0.860962  0.448736
# accelerations                                            NaN       NaN
# fetal_movement                                      0.651711 -0.334029
# uterine_contractions                               -0.894997 -0.014352
# light_decelerations                                 0.636897  0.547424
# severe_decelerations                                     NaN       NaN
# prolongued_decelerations                                 NaN       NaN
# abnormal_short_term_variability                     0.742197  0.209022
# mean_value_of_short_term_variability               -0.579798 -0.252795
# percentage_of_time_with_abnormal_long_term_vari...  0.090048  0.807717
# mean_value_of_long_term_variability                -0.479076 -0.660596
# histogram_width                                     0.289893  0.410963
# histogram_min                                      -0.736211 -0.189573
# histogram_max                                      -0.391999  0.442668
# histogram_number_of_peaks                           0.410973  0.837811
# histogram_number_of_zeroes                         -0.381635  0.640497
# histogram_mode                                     -0.939833  0.234201
# histogram_mean                                     -0.952841  0.259534
# histogram_median                                   -0.939644  0.300914
# histogram_variance                                 -0.046604 -0.510214
# histogram_tendency                                 -0.302736  0.495136
# fetal_health                                             NaN       NaN
#
#                                                       Dim. 2    Dim. 3  \
# Unnamed: 0                                          0.143050  0.540823
# baseline value                                     -0.184001 -0.034997
# accelerations                                            NaN       NaN
# fetal_movement                                     -0.260310 -0.509548
# uterine_contractions                                0.135214  0.178281
# light_decelerations                                 0.428496  0.258133
# severe_decelerations                                     NaN       NaN
# prolongued_decelerations                                 NaN       NaN
# abnormal_short_term_variability                    -0.279072 -0.240397
# mean_value_of_short_term_variability                0.696261  0.011153
# percentage_of_time_with_abnormal_long_term_vari... -0.278402  0.386655
# mean_value_of_long_term_variability                 0.294001 -0.477666
# histogram_width                                     0.850068 -0.145994
# histogram_min                                      -0.525118  0.266776
# histogram_max                                       0.760195  0.075860
# histogram_number_of_peaks                           0.333164  0.052187
# histogram_number_of_zeroes                         -0.155934 -0.489837
# histogram_mode                                     -0.064682 -0.160875
# histogram_mean                                     -0.027385 -0.093297
# histogram_median                                   -0.058577 -0.105586
# histogram_variance                                  0.661753 -0.270335
# histogram_tendency                                 -0.181014 -0.522453
# fetal_health                                             NaN       NaN
#
#                                                       Dim. 4    Dim. 5  \
# Unnamed: 0                                         -0.186516 -0.173224
# baseline value                                     -0.047912 -0.132475
# accelerations                                            NaN       NaN
# fetal_movement                                     -0.307677 -0.186025
# uterine_contractions                               -0.286645 -0.180360
# light_decelerations                                -0.080932 -0.190590
# severe_decelerations                                     NaN       NaN
# prolongued_decelerations                                 NaN       NaN
# abnormal_short_term_variability                     0.304692 -0.410483
# mean_value_of_short_term_variability               -0.253416  0.184209
# percentage_of_time_with_abnormal_long_term_vari...  0.058598  0.284199
# mean_value_of_long_term_variability                -0.009260  0.067292
# histogram_width                                    -0.051870 -0.011244
# histogram_min                                       0.210562 -0.126853
# histogram_max                                       0.162289 -0.166455
# histogram_number_of_peaks                          -0.093527 -0.074533
# histogram_number_of_zeroes                          0.306980  0.211602
# histogram_mode                                      0.150806 -0.090863
# histogram_mean                                      0.076843 -0.096719
# histogram_median                                    0.064609 -0.087741
# histogram_variance                                  0.469975 -0.023224
# histogram_tendency                                 -0.589342 -0.019747
# fetal_health                                             NaN       NaN
#
#                                                       Dim. 6    Dim. 7
# Unnamed: 0                                         -0.342596  0.311681
# baseline value                                     -0.049535  0.245147
# accelerations                                            NaN       NaN
# fetal_movement                                      0.083827 -0.118674
# uterine_contractions                                0.184427  0.480054
# light_decelerations                                -0.039661 -0.868385
# severe_decelerations                                     NaN       NaN
# prolongued_decelerations                                 NaN       NaN
# abnormal_short_term_variability                     0.091914 -0.515457
# mean_value_of_short_term_variability                0.129891  0.550091
# percentage_of_time_with_abnormal_long_term_vari...  0.168142 -0.606347
# mean_value_of_long_term_variability                 0.122002  0.916339
# histogram_width                                    -0.018021 -0.373115
# histogram_min                                       0.121278  0.523741
# histogram_max                                       0.112635  0.009122
# histogram_number_of_peaks                          -0.033901 -0.817409
# histogram_number_of_zeroes                         -0.202115  0.067447
# histogram_mode                                     -0.028303  0.522465
# histogram_mean                                     -0.004768  0.482940
# histogram_median                                   -0.008286  0.450670
# histogram_variance                                 -0.071383  0.529446
# histogram_tendency                                 -0.098761 -0.070745
# fetal_health                                             NaN       NaN

# %%
plot_circle(model, param)

# %%
plot_explained_var(model, param)

# %%
plot_var_contribution(model, param)

# %%
# plot of the projections left to do
